# %% [markdown]
# <a href="https://colab.research.google.com/github/aiyappa02/Technical-Analysis/blob/master/Inteactive_candlestick_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# To create inteactive candlestick chart in Python using Plotly

# %%
# Import libraries
import pandas as pd
import plotly.graph_objects as go
import pandas_datareader as web
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
df=web.DataReader('RELIANCE.NS',data_source="yahoo",start='2020-01-01',end='2020-07-24')
df
# Out:
#                    High          Low  ...      Volume    Adj Close
# Date                                  ...
# 2020-01-01  1527.099976  1505.500000  ...   6402372.0  1503.952881
# 2020-01-02  1540.949951  1512.000000  ...   8096561.0  1529.556763
# 2020-01-03  1541.650024  1523.000000  ...   9593498.0  1531.399902
# 2020-01-06  1527.900024  1498.000000  ...  11209343.0  1495.883179
# 2020-01-07  1534.500000  1513.500000  ...   7627191.0  1518.896729
# ...                 ...          ...  ...         ...          ...
# 2020-07-20  1932.000000  1899.650024  ...  16887635.0  1919.900024
# 2020-07-21  1977.000000  1936.500000  ...  19463004.0  1971.550049
# 2020-07-22  2010.000000  1960.699951  ...  27584518.0  2004.000000
# 2020-07-23  2079.699951  1991.349976  ...  26921017.0  2057.800049
# 2020-07-24  2163.000000  2057.800049  ...  55648411.0  2146.149902
#
# [140 rows x 6 columns]

# %%
#create candlestick chart
figure = go.Figure(
    data = go.Candlestick(
        x=df.index,
        low=df["Low"],
        high=df["High"],
        open=df["Open"],
        close=df["Close"]
    )
)
# to remove the slider
#figure.update_layout(xaxis_rangeslider_visible = False)
#to vary the height
figure.update_layout(height = 700)

figure.update_layout(
    title = "Reliance Stock Price",
    yaxis_title = "Price in $",
    xaxis_title = "Date"
)

figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="421a92fb-00ca-4e48-94c9-5a30b97fe613" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("421a92fb-00ca-4e48-94c9-5a30b97fe613")) {
#                     Plotly.newPlot(
#                         '421a92fb-00ca-4e48-94c9-5a30b97fe613',
# ...
